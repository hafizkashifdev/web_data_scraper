# %%
import json
import os
import sys
import pandas as pd

# %%
def extract_api_info_from_json_dir(base_dir, output_excel_path="api_extracted_1.xlsx"):
    """
    Recursively scans JSON files in the given base directory to extract API endpoint information,
    including full URLs, and saves the results to an Excel file.

    Handles both OpenAPI and Postman collection formats.
    """
    results = []

    def extract_postman_items(items, bank_name):
        for item in items:
            name = item.get("name", "")
            # Recurse if sub-items
            if "item" in item:
                extract_postman_items(item["item"], bank_name)
            elif "request" in item:
                req = item["request"]
                method = req.get("method", "")
                url = req.get("url")
                # url can be a string or a dict
                if isinstance(url, dict):
                    url_str = url.get("raw") or url.get("url") or ""
                    if not url_str and "host" in url and "path" in url:
                        url_str = "/".join(url.get("host", [])) + "/" + "/".join(url.get("path", []))
                else:
                    url_str = url or ""
                results.append({
                    "bank": bank_name,
                    "method": method.upper(),
                    "endpoint": url_str,
                    "url": url_str,
                    "description": name,
                    "responses": ""
                })

    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.lower().endswith('.json'):
                json_path = os.path.join(root, file)
                try:
                    with open(json_path, 'r', encoding='utf-8-sig') as f:
                        data = json.load(f)

                    rel_path = os.path.relpath(json_path, base_dir)
                    path_parts = rel_path.split(os.sep)
                    bank_name = path_parts[0] if path_parts else "Unknown"

                    # Detect OpenAPI vs Postman
                    if "paths" in data:
                        # OpenAPI
                        base_url = ""
                        servers = data.get("servers", [])
                        if isinstance(servers, list) and servers:
                            first_server = servers[0]
                            if isinstance(first_server, dict):
                                base_url = first_server.get("url", "")
                                if isinstance(base_url, str):
                                    base_url = base_url.rstrip("/")
                                else:
                                    base_url = ""
                        paths = data.get('paths', {})
                        for endpoint, methods in paths.items():
                            for method, details in methods.items():
                                if method.lower() not in ["get", "post", "put", "delete", "patch", "options", "head"]:
                                    continue
                                summary = details.get("summary", "")
                                description = details.get("description", "")
                                full_url = f"{base_url}{endpoint}" if base_url else endpoint
                                responses = details.get("responses", {})
                                formatted_responses = json.dumps(responses, indent=2) if isinstance(responses, dict) else str(responses)
                                results.append({
                                    "bank": bank_name,
                                    "method": method.upper(),
                                    "endpoint": endpoint,
                                    "url": full_url,
                                    "description": summary or description,
                                    "responses": formatted_responses
                                })
                    elif "item" in data:
                        # Postman Collection
                        extract_postman_items(data["item"], bank_name)
                except json.JSONDecodeError as e:
                    print(f"JSON decode error in {json_path}: {e}")
                except Exception as e:
                    print(f"Error processing {json_path}: {e}")

    # # Print results
    # for item in results:
    #     print(f"{item['bank']} | {item['method']:6} {item['endpoint']:40} {item['url']:50} {item['description']}")

    # Save to Excel
    if results:
        df = pd.DataFrame(results)
        df.to_excel(output_excel_path, index=False)
        # print(f"Results saved to {output_excel_path}")
    else:
        print("No API information found.")

    return results

# %%
# def extract_api_info_from_json_dir(base_dir, output_excel_path="api_extracted.xlsx"):
#     """
#     Recursively scans JSON files in the given base directory to extract API endpoint information,
#     including full URLs, and saves the results to an Excel file.

#     For each API, the bank name is extracted from the OpenAPI info.title field if available.

#     Parameters:
#         base_dir (str): The directory to scan.
#         output_excel_path (str): Path to save the resulting Excel file.

#     Returns:
#         list: A list of dictionaries with API information.
#     """
#     results = []

#     for root, dirs, files in os.walk(base_dir):
#         for file in files:
#             if file.lower().endswith('.json'):
#                 json_path = os.path.join(root, file)
#                 try:
#                     with open(json_path, 'r', encoding='utf-8-sig') as f:
#                         data = json.load(f)

#                     # Safely extract base_url
#                     base_url = ""
#                     servers = data.get("servers", [])
#                     if isinstance(servers, list) and servers:
#                         first_server = servers[0]
#                         if isinstance(first_server, dict):
#                             base_url = first_server.get("url", "")
#                             if isinstance(base_url, str):
#                                 base_url = base_url.rstrip("/")
#                             else:
#                                 base_url = ""

#                     # Always use the top-level directory under base_dir as the bank name
#                     rel_path = os.path.relpath(json_path, base_dir)
#                     path_parts = rel_path.split(os.sep)
#                     bank_name = path_parts[0] if path_parts else "Unknown"

#                     paths = data.get('paths', {})
#                     for endpoint, methods in paths.items():
#                         for method, details in methods.items():
#                             if method.lower() not in ["get", "post", "put", "delete", "patch", "options", "head"]:
#                                 continue
#                             summary = details.get("summary", "")
#                             description = details.get("description", "")
#                             full_url = f"{base_url}{endpoint}" if base_url else endpoint

#                             # Get responses as JSON string
#                             responses = details.get("responses", {})
#                             if isinstance(responses, dict):
#                                 formatted_responses = json.dumps(responses, indent=2)
#                             else:
#                                 formatted_responses = str(responses)

#                             results.append({
#                                 "bank": bank_name,
#                                 "method": method.upper(),
#                                 "endpoint": endpoint,
#                                 "url": full_url,
#                                 "description": summary or description,
#                                 "responses": formatted_responses
#                             })
#                 except json.JSONDecodeError as e:
#                     print(f"JSON decode error in {json_path}: {e}")
#                 except Exception as e:
#                     print(f"Error processing {json_path}: {e}")

#     # Print results
#     for item in results:
#         print(f"{item['bank']} | {item['method']:6} {item['endpoint']:40} {item['url']:50} {item['description']}")


#     # Save to Excel
#     if results:
#         df = pd.DataFrame(results)
#         df.to_excel(output_excel_path, index=False)
#         print(f"Results saved to {output_excel_path}")
#     else:
#         print("No API information found.")

#     return results

# %%
extract_api_info_from_json_dir("Banks API's json files")
# Out:
# [{'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'url': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'description': 'Retrieve packages',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'url': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'description': 'Retrieve transaction account product summary',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'url': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'description': 'Retrieve deposit account product summary',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'url': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'description': 'Retrieve term & maturity product summary',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'url': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'description': 'Retrieve loan product summary',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'url': 'https://api.sandbox.10xbanking.com/v2/products//versions//summary',
#   'description': 'Retrieve credit card product summary',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'description': 'Create an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals/',
#   'description': 'Retrieve an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals/',
#   'description': 'Update an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PATCH',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals/',
#   'description': 'Modify an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/businesses',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/businesses',
#   'description': 'Create a business party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/businesses/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/businesses/',
#   'description': 'Retrieve a business party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/businesses/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/businesses/',
#   'description': 'Update a business party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/:id/state',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/:id/state',
#   'description': 'Retrieve party state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/:id/state/transition',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/:id/state/transition',
#   'description': 'Transition party state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'description': 'Create a transaction account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'description': 'Create a deposit account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'description': 'Create a term & maturity account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/search?returnBalances=true',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/search?returnBalances=true',
#   'description': 'Search for subscriptions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/',
#   'description': 'Get subscription details for transaction account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PATCH',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/',
#   'description': 'Update name of deposit subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'description': 'Generate a settlement quote for a subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/parties//products//terms-and-conditions/accept',
#   'url': 'https://api.sandbox.10xbanking.com/v1/parties//products//terms-and-conditions/accept',
#   'description': 'Accept terms & conditions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'description': 'Create a 100 overdraft in offered state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'description': 'Accept the overdraft offer',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'description': 'Search for overdrafts by partyKey',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/lending/repayments/schedules/quote',
#   'url': 'https://api.sandbox.10xbanking.com/v1/lending/repayments/schedules/quote',
#   'description': 'Generate a loan quote',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'description': 'Create the unsecured loan in initial state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'description': 'Accept the loan offer',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'description': 'Retrieve the loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'description': 'Disburse the 5000 loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'description': 'Retrieve activated loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'description': 'Search for loan by partyKey',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve current loan repayment schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'url': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'description': 'Search for customer transactions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'description': 'Generate a settlement quote for a loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'description': 'Adjust the loan term to add 3 months to term',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve adjusted loan schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'description': 'Adjust loan to interest only',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve adjusted loan schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'description': 'Update next payment date and/or frequency of loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve adjusted loan schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/lending-collateral',
#   'url': 'https://api.sandbox.10xbanking.com/v2/lending-collateral',
#   'description': 'Create lending collateral',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PATCH',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/lending-collateral/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/lending-collateral/',
#   'description': 'Update lending collateral',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/lending/repayments/schedules/quote',
#   'url': 'https://api.sandbox.10xbanking.com/v1/lending/repayments/schedules/quote',
#   'description': 'Generate a loan repayment quote',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'description': 'Book the secured loan in initial state, with no overrides',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'description': 'Accept the loan offer',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'description': 'Retrieve the loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'description': 'Disburse the 5000 secured loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'description': 'Retrieve activated loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'description': 'Search for loan by partyKey',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve current loan repayment schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'description': 'Generate a settlement quote for a loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'description': 'Adjust the loan term to add 3 months to term',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve adjusted loan schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'description': 'Adjust loan to interest only',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve adjusted loan schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//schedules//versions',
#   'description': 'Update next payment date and/or frequency of loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve adjusted loan schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/',
#   'description': 'Credit the term & maturity account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'description': 'Debit a customer account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/batch',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/batch',
#   'description': 'Submit a batch of debits/credits',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'url': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'description': 'Search for customer transactions via GraphQL',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/transactions/pay-ex-gratia',
#   'url': 'https://api.sandbox.10xbanking.com/v1/transactions/pay-ex-gratia',
#   'description': 'Pay Ex Gratia',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//holds',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//holds',
#   'description': 'Create a hold on a subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//holds',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//holds',
#   'description': 'Retrieve holds on a subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions',
#   'description': 'Initiate a notice instruction',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions/search',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions/search',
#   'description': 'Search for notice instructions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-withdrawal-quotation',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-withdrawal-quotation',
#   'description': 'Generate quote for withdrawal on notice account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions',
#   'description': 'Initiate a notice instruction',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions/search',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions/search',
#   'description': 'Search for notice instructions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-withdrawal-quotation',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-withdrawal-quotation',
#   'description': 'Generate quote for withdrawal on notice account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PATCH',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions/751efb91-83b6-4492-96e8-d24a53365e19/state/CANCELLED',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//notice-instructions/751efb91-83b6-4492-96e8-d24a53365e19/state/CANCELLED',
#   'description': 'Update the state of the notice instruction',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/overrides/credit-interest',
#   'url': 'https://api.sandbox.10xbanking.com/v2/overrides/credit-interest',
#   'description': 'Create Credit Interest Override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest/',
#   'url': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest/',
#   'description': 'Retrieve existing credit interest override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/overrides/credit-interest/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/overrides/credit-interest/',
#   'description': 'Update Credit Interest Override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest//apply?dryRun=false',
#   'url': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest//apply?dryRun=false',
#   'description': 'Apply a credit interest override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest//adjust',
#   'url': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest//adjust',
#   'description': 'Adjust a credit interest override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest/timelines',
#   'url': 'https://api.sandbox.10xbanking.com/v1/overrides/credit-interest/timelines',
#   'description': 'Retrieve a credit interest timeline',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/overrides/debit-interest',
#   'url': 'https://api.sandbox.10xbanking.com/v3/overrides/debit-interest',
#   'description': 'Create Debit Interest Override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest/',
#   'description': 'Retrieve existing debit interest override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/overrides/debit-interest/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/overrides/debit-interest/',
#   'description': 'Update Debit Interest Override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest//apply?dryRun=false',
#   'url': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest//apply?dryRun=false',
#   'description': 'Apply a debit interest override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest/:id/adjust',
#   'url': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest/:id/adjust',
#   'description': 'Adjust a credit interest override',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest/timelines',
#   'url': 'https://api.sandbox.10xbanking.com/v2/overrides/debit-interest/timelines',
#   'description': 'Retrieve a debit interest timeline',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//maturity',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//maturity',
#   'description': 'Retrieve maturity date for a subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//funding-period',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//funding-period',
#   'description': 'Retrieve funding period',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//convert',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//convert',
#   'description': 'Convert subscription to target product',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/:id/goals?goalType=budget',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/:id/goals?goalType=budget',
#   'description': 'Create a spending limit on transaction account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/:id/goals?goalType=target',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/:id/goals?goalType=target',
#   'description': 'Create a savings target on deposit account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/goals?subscriptionKeys=',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/goals?subscriptionKeys=',
#   'description': 'Retrieve all goals on transaction account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'DELETE',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=budget',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=budget',
#   'description': 'Delete a spending limit',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'DELETE',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=target',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=target',
#   'description': 'Delete a savings target',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweepTypes',
#   'url': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweepTypes',
#   'description': 'Retrieve available sweep types',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps',
#   'url': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps',
#   'description': 'Retrieve all active sweep rules',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps',
#   'url': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps',
#   'description': 'Create a new round-up sweep for a subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps/',
#   'url': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps/',
#   'description': 'Retrieve a specific sweep rule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps/',
#   'url': 'https://api.sandbox.10xbanking.com/v1/subscriptions//autosweeps/',
#   'description': 'Update an existing sweep rule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v4/parties//documents',
#   'url': 'https://api.sandbox.10xbanking.com/v4/parties//documents',
#   'description': 'Create a new party document',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/parties//documents',
#   'url': 'https://api.sandbox.10xbanking.com/v1/parties//documents',
#   'description': 'Retrieve party documents',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PATCH',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v4/parties//documents/',
#   'url': 'https://api.sandbox.10xbanking.com/v4/parties//documents/',
#   'description': 'Update the party document metadata',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v4/parties//documents//content',
#   'url': 'https://api.sandbox.10xbanking.com/v4/parties//documents//content',
#   'description': 'Retrieve party document content',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/parties//conversations',
#   'url': 'https://api.sandbox.10xbanking.com/v1/parties//conversations',
#   'description': 'Retrieve chat conversations',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/parties//conversations',
#   'url': 'https://api.sandbox.10xbanking.com/v1/parties//conversations',
#   'description': 'Create a new chat conversation',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/conversations//messages?limit=10',
#   'url': 'https://api.sandbox.10xbanking.com/v3/conversations//messages?limit=10',
#   'description': 'Retrieve chat conversation messages',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/conversations//messages',
#   'url': 'https://api.sandbox.10xbanking.com/v3/conversations//messages',
#   'description': 'Add a new message to a chat conversation',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'url': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'description': 'Calculate rate credit interest',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'url': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'description': 'Calculate rate debit interest',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'url': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'description': 'Calculate rate multi rate interest',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'description': 'Create an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'description': 'Transition party state to provisioned',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'url': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'description': 'Retrieve available products',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'description': 'Open a transaction account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'description': 'Create a 100 overdraft in offered state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'description': 'Accept the overdraft offer',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/:id?balanceCheck=true',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/:id?balanceCheck=true',
#   'description': 'Debit the customer account into authorised overdraft',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/',
#   'description': 'Credit the customer account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/arrangements/search',
#   'url': 'https://api.sandbox.10xbanking.com/v1/arrangements/search',
#   'description': 'Search for overdrafts by partyKey',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'url': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'description': 'Search for customer transactions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=budget',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=budget',
#   'description': 'Create a spending limit',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'description': 'Create an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'description': 'Transition party state to provisioned',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'url': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'description': 'Retrieve available products',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'description': 'Create a deposit account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PATCH',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/',
#   'description': 'Update name of deposit account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=target',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=target',
#   'description': 'Create a savings target',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions/goals?subscriptionKeys=',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions/goals?subscriptionKeys=',
#   'description': 'Retrieve all goals',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/',
#   'description': 'Credit the customer account',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'url': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'description': 'Search for customer transactions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'url': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'description': 'Calculate rate credit interest',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'description': 'Create an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'description': 'Transition party state to provisioned',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'url': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'description': 'Retrieve available products',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/lending/repayments/schedules/quote',
#   'url': 'https://api.sandbox.10xbanking.com/v1/lending/repayments/schedules/quote',
#   'description': 'Generate a loan quote',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'description': 'Create the unsecured loan in initial state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'description': 'Accept the loan offer',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'description': 'Retrieve the loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/?balanceCheck=true',
#   'description': 'Disburse the 5000 loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/',
#   'description': 'Retrieve activated loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'description': 'Search for loan by partyKey',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'url': 'https://api.sandbox.10xbanking.com/v1/schedules//versions/latest',
#   'description': 'Retrieve current loan repayment schedule',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'url': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'description': 'Search for customer transactions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//settlement-quote',
#   'description': 'Generate a settlement quote for a loan',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'url': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'description': 'Calculate rate debit interest',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties/individuals',
#   'description': 'Create an individual party',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'url': 'https://api.sandbox.10xbanking.com/v2/parties//state/transition',
#   'description': 'Transition party state to provisioned',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'GET',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'url': 'https://api.sandbox.10xbanking.com/v2/packages/public',
#   'description': 'Retrieve available products',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions',
#   'description': 'Open a credit card subscription',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements',
#   'description': 'Create a 10000 credit card in offered state',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'url': 'https://api.sandbox.10xbanking.com/v2/arrangements//accept',
#   'description': 'Accept the credit card offer',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v2/transactions/:id?balanceCheck=true',
#   'url': 'https://api.sandbox.10xbanking.com/v2/transactions/:id?balanceCheck=true',
#   'description': 'Complete first purchase on credit card',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'url': 'https://api.sandbox.10xbanking.com/v3/arrangements/search?limit=1',
#   'description': 'Search for lending products by partyKey',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'url': 'https://api.sandbox.10xbanking.com/v1/insights',
#   'description': 'Search for customer transactions',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'PUT',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=budget',
#   'url': 'https://api.sandbox.10xbanking.com/v3/subscriptions//goals?goalType=budget',
#   'description': 'Create a spending limit',
#   'responses': ''},
#  {'bank': '10x banking',
#   'method': 'POST',
#   'endpoint': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'url': 'https://api.sandbox.10xbanking.com/v1/interests/calculate-rate',
#   'description': 'Calculate rate multi rate interest',
#   'responses': ''},
#  {'bank': 'adyen',
#   'method': 'POST',
#   'endpoint': '/closeAccount',
#   'url': 'https://cal-test.adyen.com/cal/services/Account/v3/closeAccount',
#   'description': 'Close an account',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/CloseAccountResponse"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "202": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/CloseAccountResponse"\n        }\n      }\n    },\n    "description": "Accepted - the request has been accepted for processing, but the processing has not been completed."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "generic": {\n            "$ref": "#/components/examples/generic-400"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "generic": {\n            "$ref": "#/components/examples/generic-403"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'POST',
#   'endpoint': '/closeAccountHolder',
#   'url': 'https://cal-test.adyen.com/cal/services/Account/v3/closeAccountHolder',
#   'description': 'Close an account holder',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/CloseAccountHolderResponse"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "202": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/CloseAccountHolderResponse"\n        }\n      }\n    },\n    "description": "Accepted - the request has been accepted for processing, but the processing has not been completed."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "generic": {\n            "$ref": "#/components/examples/generic-400"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "generic": {\n            "$ref": "#/components/examples/generic-403"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/ServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'POST',
#   'endpoint': '/createAccount',
#   'url': 'https://cal-test.adyen.com/cal/services/Account/v3/createAccount',
#   'description': 'Create an account',
# ...
#  {'bank': 'adyen',
#   'method': 'POST',
#   'endpoint': '/stores',
#   'url': 'https://management-test.adyen.com/v1/stores',
#   'description': 'Create a store',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "post-stores": {\n            "$ref": "#/components/examples/post-stores-post-stores-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/Store"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'GET',
#   'endpoint': '/stores/{storeId}',
#   'url': 'https://management-test.adyen.com/v1/stores/{storeId}',
#   'description': 'Get a store',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "success": {\n            "$ref": "#/components/examples/get-stores-storeId-success-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/Store"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'PATCH',
#   'endpoint': '/stores/{storeId}',
#   'url': 'https://management-test.adyen.com/v1/stores/{storeId}',
#   'description': 'Update a store',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "patch-stores": {\n            "$ref": "#/components/examples/patch-stores-storeId-patch-stores-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/Store"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'GET',
#   'endpoint': '/stores/{storeId}/terminalLogos',
#   'url': 'https://management-test.adyen.com/v1/stores/{storeId}/terminalLogos',
#   'description': 'Get the terminal logo',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "success": {\n            "$ref": "#/components/examples/get-stores-storeId-terminalLogos-success-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/Logo"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'PATCH',
#   'endpoint': '/stores/{storeId}/terminalLogos',
#   'url': 'https://management-test.adyen.com/v1/stores/{storeId}/terminalLogos',
#   'description': 'Update the terminal logo',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "remove-logo": {\n            "$ref": "#/components/examples/patch-stores-storeId-terminalLogos-remove-logo-200"\n          },\n          "upload-logo": {\n            "$ref": "#/components/examples/patch-stores-storeId-terminalLogos-upload-logo-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/Logo"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'GET',
#   'endpoint': '/stores/{storeId}/terminalSettings',
#   'url': 'https://management-test.adyen.com/v1/stores/{storeId}/terminalSettings',
#   'description': 'Get terminal settings',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "success": {\n            "$ref": "#/components/examples/get-stores-storeId-terminalSettings-success-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/TerminalSettings"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'PATCH',
#   'endpoint': '/stores/{storeId}/terminalSettings',
#   'url': 'https://management-test.adyen.com/v1/stores/{storeId}/terminalSettings',
#   'description': 'Update terminal settings',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "add-eap-peap-and-psk-wifi-profiles": {\n            "$ref": "#/components/examples/patch-stores-storeId-terminalSettings-add-eap-peap-and-psk-wifi-profiles-200"\n          },\n          "add-eap-tls-wifi-profile": {\n            "$ref": "#/components/examples/patch-stores-storeId-terminalSettings-add-eap-tls-wifi-profile-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/TerminalSettings"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  {'bank': 'adyen',
#   'method': 'GET',
#   'endpoint': '/terminals',
#   'url': 'https://management-test.adyen.com/v1/terminals',
#   'description': 'Get a list of terminals',
#   'responses': '{\n  "200": {\n    "content": {\n      "application/json": {\n        "examples": {\n          "success": {\n            "$ref": "#/components/examples/get-terminals-success-200"\n          }\n        },\n        "schema": {\n          "$ref": "#/components/schemas/ListTerminalsResponse"\n        }\n      }\n    },\n    "description": "OK - the request has succeeded."\n  },\n  "400": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Bad Request - a problem reading or understanding the request."\n  },\n  "401": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unauthorized - authentication required."\n  },\n  "403": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Forbidden - insufficient permissions to process the request."\n  },\n  "422": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Unprocessable Entity - a request validation error."\n  },\n  "500": {\n    "content": {\n      "application/json": {\n        "schema": {\n          "$ref": "#/components/schemas/RestServiceError"\n        }\n      }\n    },\n    "description": "Internal Server Error - the server could not process the request."\n  }\n}'},
#  ...]
